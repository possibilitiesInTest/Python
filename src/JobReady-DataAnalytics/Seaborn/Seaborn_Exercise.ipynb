# %%
# import pandas, numpy, seaborn

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import dataset

# %%
cereal = pd.read_csv('cereal.csv')
cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
# plot a histogram without kde curve but with the rugplot for the carbo column of the 'cereal' dataframe
# find which row has negative carbo value

# plot a histogram with kde curve for fiber column of 'cereal' dataframe
# find which row has the highest fiber value

# %%
sns.displot(cereal['carbo'], bins=10, kde=False, rug=True)
# Out:
# C:\Users\goura\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cereal[cereal['carbo']<0]
# Out:
#               name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 57  Quaker Oatmeal   Q    H       100        5    2       0    2.7   -1.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 57      -1     110         0      1     1.0  0.67  50.828392

# %%
sns.displot(cereal['fiber'], kde=True)
# Out:
# C:\Users\goura\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cereal[cereal['fiber']==cereal['fiber'].max()]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %%
# create a joint plot for carbo and fiber columns of the cereals dataframe to find out if more fiber leads to more carbs

# %%
sns.set_style('darkgrid')
sns.jointplot(x='carbo', y='fiber', data=cereal, kind='hex')

# %%
# create a pairplot for all numerical columns in the cereal dataframe

# %%
sns.pairplot(data=cereal)
# Out:
# C:\Users\goura\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# create a plot of counts of cereals from the various manufacturers (column = mfr)

# %%
sns.countplot(x='mfr', data=cereal)
# Out:
# <Axes: xlabel='mfr', ylabel='count'>

# %%
# create a strip plot showing ratings separated by each manufacturer
# create a box plot showing the variation of sodium in cereals separated by each manufacturer
# is there a correlation?

# %%
sns.stripplot(x='mfr', y='rating', data=cereal, hue="name")
# Out:
# <Axes: xlabel='mfr', ylabel='rating'>

# %%
sns.boxplot(x='mfr', y='sodium', data=cereal)
# Out:
# <Axes: xlabel='mfr', ylabel='sodium'>

# %%
# create a correlation matrix using the corr function
# create a heatmap of the correlation matrix
# which combination has the highest correlation?

# %%
cereal.corr(numeric_only=True)
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %%
sns.heatmap(cereal.corr(numeric_only=True), cmap='coolwarm')
# Out:
# <Axes: >

# %%
# fiber and potassium

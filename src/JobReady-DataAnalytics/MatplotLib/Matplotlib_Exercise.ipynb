# %%
#import pandas, numpy, pyplot from matplotlib libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import data using the statement below

# %%
seAsia = pd.read_csv('WHO-COVID-19-SEAsia.csv')

# %%
seAsia['Country'].unique()
# Out:
# array(['Bangladesh', 'Bhutan', 'India', 'Indonesia', 'Maldives',
#        'Myanmar', 'Nepal', 'Sri Lanka', 'Thailand', 'Timor-Leste'],
#       dtype=object)

# %%
# create a new DataFrame 'india' from 'seAsia' where the country is India
# plot x=Date_reported with y=Cumulative_cases where the country is India

# %%
india = seAsia[seAsia["Country"]=="India"]
india
# Out:
#                  Date_reported Country_code Country WHO_region  New_cases  \
# 196  2020-01-30 00:00:00+00:00           IN   India      SEARO          1
# 197  2020-01-31 00:00:00+00:00           IN   India      SEARO          0
# 198  2020-02-01 00:00:00+00:00           IN   India      SEARO          0
# 199  2020-02-02 00:00:00+00:00           IN   India      SEARO          1
# 200  2020-02-03 00:00:00+00:00           IN   India      SEARO          1
# ..                         ...          ...     ...        ...        ...
# 326  2020-06-08 00:00:00+00:00           IN   India      SEARO       9983
# 327  2020-06-09 00:00:00+00:00           IN   India      SEARO       9987
# 328  2020-06-10 00:00:00+00:00           IN   India      SEARO       9985
# 329  2020-06-11 00:00:00+00:00           IN   India      SEARO       9996
# 330  2020-06-12 00:00:00+00:00           IN   India      SEARO      10956
#
#      Cumulative_cases  New_deaths  Cumulative_deaths
# 196                 1           0                  0
# 197                 1           0                  0
# 198                 1           0                  0
# 199                 2           0                  0
# 200                 3           0                  0
# ..                ...         ...                ...
# 326            256611         206               7135
# 327            266598         331               7466
# 328            276583         279               7745
# 329            286579         357               8102
# 330            297535         396               8498
#
# [135 rows x 8 columns]

# %%
plt.plot(india['Date_reported'],india['Cumulative_cases'])

# %%
# plot x=Date_reported with y=New_cases where the country is India using the Object Oriented Method
# and a figure size of 15 by 5

# %%
fig = plt.figure(figsize=(15,5))

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(india['Date_reported'], india['New_cases'])

# %%
# create a new DataFrame 'bangla' from 'seAsia' where the country is Bangladesh
# plot two subplots (2 rows and 1 column of plots)
#  - top plot should have x=Date_reported and y=New_cases for india
#  - bottom plot should have x=Date_reported and y=New_cases for bangla
#  - each plot should have a title and labels for x-axis and y-axis

# %%
bangla = seAsia[seAsia['Country']=='Bangladesh']
bangla
# Out:
#                 Date_reported Country_code     Country WHO_region  New_cases  \
# 0   2020-03-08 00:00:00+00:00           BD  Bangladesh      SEARO          3
# 1   2020-03-09 00:00:00+00:00           BD  Bangladesh      SEARO          0
# 2   2020-03-10 00:00:00+00:00           BD  Bangladesh      SEARO          0
# 3   2020-03-11 00:00:00+00:00           BD  Bangladesh      SEARO          0
# 4   2020-03-12 00:00:00+00:00           BD  Bangladesh      SEARO          0
# ..                        ...          ...         ...        ...        ...
# 92  2020-06-08 00:00:00+00:00           BD  Bangladesh      SEARO       2743
# 93  2020-06-09 00:00:00+00:00           BD  Bangladesh      SEARO       2735
# 94  2020-06-10 00:00:00+00:00           BD  Bangladesh      SEARO       3171
# 95  2020-06-11 00:00:00+00:00           BD  Bangladesh      SEARO       3190
# 96  2020-06-12 00:00:00+00:00           BD  Bangladesh      SEARO       3187
#
#     Cumulative_cases  New_deaths  Cumulative_deaths
# 0                  3           0                  0
# 1                  3           0                  0
# 2                  3           0                  0
# 3                  3           0                  0
# 4                  3           0                  0
# ..               ...         ...                ...
# 92             65769          42                888
# 93             68504          42                930
# 94             71675          45                975
# 95             74865          37               1012
# 96             78052          37               1049
#
# [97 rows x 8 columns]

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15,10))

axes[0].plot(india['Date_reported'], india['New_cases'])
axes[0].set_title('Daily New Cases for India')
axes[0].set_xlabel('Date Reported')
axes[0].set_ylabel('New Cases')


axes[1].plot(bangla['Date_reported'], bangla['New_cases'])
axes[1].set_title('Daily New Cases for Bangladesh')
axes[1].set_xlabel('Date Reported')
axes[1].set_ylabel('New Cases')
# Out:
# Text(0, 0.5, 'New Cases')

# %%
# combine the two plots into a single plot with a legend to differentiate the line for each country

# %%
fig = plt.figure(figsize=(15,5))

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(india['Date_reported'], india['New_cases'], label='India')
axes.plot(bangla['Date_reported'], bangla['New_cases'], label='Bangladesh')

axes.set_title('Daily New Cases for India and Bangladesh')
axes.set_xlabel('Date Reported')
axes.set_ylabel('New Cases')
axes.legend()
